# %%
import pandas as pd

# %%
# (1) Используя параметры pandas прочитать красиво пандас (подвох что заголовки - первые 2 линии)
df = pd.read_csv('default_of_credit_card_clients.csv', skiprows=1, delimiter=';', index_col='ID')
#for col in df.columns:
#    if col.startswith('BILL_') | col.startswith('PAY_') | col.endswith('_BAL'):
#        df[col] = df[col].astype('float')
#    else:
#        df[col] = df[col].astype('object')

# %%
df.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
#
#     PAY_5             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID                    ...
# 1      -2             ...                      0          0          0
# 2       0             ...                   3272       3455       3261
# 3       0             ...                  14331      14948      15549
# 4       0             ...                  28314      28959      29547
# 5       0             ...                  20940      19146      19131
#
#     PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
# (2) выведите, что за типы переменных, сколько пропусков,
# для численных значений посчитайте пару статистик (в свободной форме)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# ...

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 

len(df[
    (df.SEX == 2) & (df.EDUCATION == 2)
])
# Out:
# 8656

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
cols = []
for col in df.columns:
    if col.startswith('BILL_') | col.startswith('PAY_'):
        cols.append(col)
df.groupby('default payment next month')[cols].median().T
# Out:
# default payment next month        0        1
# PAY_0                           0.0      1.0
# PAY_2                           0.0      0.0
# PAY_3                           0.0      0.0
# PAY_4                           0.0      0.0
# PAY_5                           0.0      0.0
# PAY_6                           0.0      0.0
# BILL_AMT1                   23119.5  20185.0
# BILL_AMT2                   21660.5  20300.5
# BILL_AMT3                   20202.5  19834.5
# BILL_AMT4                   19000.0  19119.5
# BILL_AMT5                   17998.0  18478.5
# BILL_AMT6                   16679.0  18028.5
# PAY_AMT1                     2459.5   1636.0
# PAY_AMT2                     2247.5   1533.5
# PAY_AMT3                     2000.0   1222.0
# PAY_AMT4                     1734.0   1000.0
# PAY_AMT5                     1765.0   1000.0
# PAY_AMT6                     1706.0   1000.0

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE

df.pivot_table(index=['SEX', 'EDUCATION'], columns=['MARRIAGE'], values='LIMIT_BAL', aggfunc='count')
# Out:
# MARRIAGE          0       1       2     3
# SEX EDUCATION
# 1   0           NaN     2.0     6.0   NaN
#     1           1.0  1690.0  2633.0  30.0
#     2           1.0  2370.0  2940.0  63.0
#     3          12.0  1048.0   894.0  36.0
#     4           NaN    18.0    23.0   1.0
#     5           NaN    48.0    46.0   1.0
#     6           NaN    14.0    11.0   NaN
# 2   0           NaN     2.0     4.0   NaN
#     1           3.0  2032.0  4176.0  20.0
#     2           5.0  4472.0  4080.0  99.0
#     3          32.0  1813.0  1015.0  67.0
#     4           NaN    34.0    45.0   2.0
#     5           NaN   102.0    81.0   2.0
#     6           NaN    14.0    10.0   2.0

# %%
# (6) Создать новый строковый столбец в data frame-е, который:
# принимает значение A, если значение LIMIT_BAL <=10000
# принимает значение B, если значение LIMIT_BAL <=100000 и >10000
# принимает значение C, если значение LIMIT_BAL <=200000 и >100000
# принимает значение D, если значение LIMIT_BAL <=400000 и >200000
# принимает значение E, если значение LIMIT_BAL <=700000 и >400000
# принимает значение F, если значение LIMIT_BAL >700000

def f(x):
    return {
                  x <=  10000: 'A',
          10000 < x <= 100000: 'B',
         100000 < x <= 200000: 'C',
         200000 < x <= 400000: 'D',
         400000 < x <= 700000: 'E',
         700000 < x          : 'F'
    }[True]

df['LIMIT_TYPE'] = df.LIMIT_BAL.map(f)
df[['LIMIT_BAL','LIMIT_TYPE']].head()
# Out:
#     LIMIT_BAL LIMIT_TYPE
# ID
# 1       20000          B
# 2      120000          C
# 3       90000          B
# 4       50000          B
# 5       50000          B

# %%
# %matplotlib inline

# %%
# (7) постироить распределение LIMIT_BAL (гистрограмму)

df['LIMIT_BAL'].hist(bins=50)

# %%
# (8) построить зависимость кредитного лимита от образования для каждого пола
# график необходимо сделать очень широким (на весь экран)

from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
df.pivot_table(values='LIMIT_BAL', index='EDUCATION', columns='SEX').plot(kind='bar', ax=ax)

# %%
# (9) построить зависимость кредитного лимита и образования только для одного из полов

fig, ax = plt.subplots(figsize=(16,8), ncols=2)
df[df['SEX'] == 1].pivot_table(values='LIMIT_BAL', index='EDUCATION').plot(kind='bar', ax=ax[0], title='М', color='lightblue')
df[df['SEX'] == 2].pivot_table(values='LIMIT_BAL', index='EDUCATION').plot(kind='bar', ax=ax[1], title='Ж', color='pink')

# %%
# (10) построить большой график (подсказка - используя seaborn) для построения завимисости всех возможных пар параметров
# разным цветом выделить разные значение "default payment next month"
# (но так как столбцов много - картинка может получиться "монструозной")
# (поэкспериментируйте над тем как построить подобное сравнение параметров)
# (подсказка - ответ может состоять из несколькольких графиков)
# (если не выйдет - программа минимум - построить один график со всеми параметрами)
import seaborn as sns

# %%
# выберем топ 5 наименее коррелируемых признаков
top_cols = df.corr().abs().mean().sort_values().head(5).index.values
sns.pairplot(df[top_cols], hue='default payment next month')

# %%
# сгруппируем связанные между собой признаки

df2 = pd.DataFrame(df)
df2['PAY'] = df['PAY_0'] + df['PAY_2'] + df['PAY_3'] + df['PAY_4'] + df['PAY_5'] + df['PAY_6']
df2['BILL_AMT'] = df['BILL_AMT1'] + df['BILL_AMT2'] + df['BILL_AMT3'] + df['BILL_AMT4'] + df['BILL_AMT5'] + df['BILL_AMT6']
df2['PAY_AMT'] = df['PAY_AMT1'] + df['PAY_AMT2'] + df['PAY_AMT3'] + df['PAY_AMT4'] + df['PAY_AMT5'] + df['PAY_AMT6']
df2.drop(['PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6',
          'BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6',
          'PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6'],
          axis=1, inplace=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 10 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# default payment next month    30000 non-null int64
# LIMIT_TYPE                    30000 non-null object
# PAY                           30000 non-null int64
# BILL_AMT                      30000 non-null int64
# PAY_AMT                       30000 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 2.5+ MB

# %%
sns.pairplot(df2, hue='default payment next month')
